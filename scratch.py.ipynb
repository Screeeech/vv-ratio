# %%
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
import nasdaq_api as na

# %%
aggs = na.getHistoricalData("AAPL").data

# %%
aggs
# Out:
# b'{"ticker":"AAPL","queryCount":252,"resultsCount":252,"adjusted":true,"results":[{"v":9.690649e+07,"vw":129.6322,"o":127.82,"c":130.48,"h":130.54,"l":127.07,"t":1623643200000,"n":563595},{"v":6.2725532e+07,"vw":129.8358,"o":129.94,"c":129.64,"h":130.6,"l":129.39,"t":1623729600000,"n":416230},{"v":9.1793025e+07,"vw":130.0001,"o":130.37,"c":130.15,"h":130.89,"l":128.461,"t":1623816000000,"n":619028},{"v":9.6721669e+07,"vw":131.5645,"o":129.8,"c":131.79,"h":132.55,"l":129.65,"t":1623902400000,"n":652025},{"v":1.08890309e+08,"vw":130.7868,"o":130.71,"c":130.46,"h":131.51,"l":130.24,"t":1623988800000,"n":557039},{"v":7.9269216e+07,"vw":131.4999,"o":130.3,"c":132.3,"h":132.41,"l":129.21,"t":1624248000000,"n":506660},{"v":7.3713618e+07,"vw":133.0905,"o":132.13,"c":133.98,"h":134.08,"l":131.62,"t":1624334400000,"n":481082},{"v":6.02142e+07,"vw":133.7872,"o":133.77,"c":133.7,"h":134.32,"l":133.23,"t":1624420800000,"n":424752},{"v":6.8710998e+07,"vw":133.7663,"o":134.45,"c":133.41,"h":134.64,
# ...

# %%
import json

# %%
a = aggs.decode('utf8'.replace("''", '""'))

# %%
b = json.loads(a)

# %%
b['results']
# Out:
# [{'v': 96906490.0,
#   'vw': 129.6322,
#   'o': 127.82,
#   'c': 130.48,
#   'h': 130.54,
#   'l': 127.07,
#   't': 1623643200000,
#   'n': 563595},
#  {'v': 62725532.0,
#   'vw': 129.8358,
#   'o': 129.94,
#   'c': 129.64,
#   'h': 130.6,
#   'l': 129.39,
#   't': 1623729600000,
#   'n': 416230},
#  {'v': 91793025.0,
#   'vw': 130.0001,
#   'o': 130.37,
#   'c': 130.15,
#   'h': 130.89,
#   'l': 128.461,
#   't': 1623816000000,
#   'n': 619028},
#  {'v': 96721669.0,
#   'vw': 131.5645,
#   'o': 129.8,
#   'c': 131.79,
#   'h': 132.55,
#   'l': 129.65,
#   't': 1623902400000,
#   'n': 652025},
#  {'v': 108890309.0,
#   'vw': 130.7868,
#   'o': 130.71,
#   'c': 130.46,
#   'h': 131.51,
#   'l': 130.24,
#   't': 1623988800000,
#   'n': 557039},
#  {'v': 79269216.0,
#   'vw': 131.4999,
#   'o': 130.3,
#   'c': 132.3,
#   'h': 132.41,
#   'l': 129.21,
#   't': 1624248000000,
#   'n': 506660},
#  {'v': 73713618.0,
#   'vw': 133.0905,
#   'o': 132.13,
#   'c': 133.98,
#   'h': 134.08,
# ...
